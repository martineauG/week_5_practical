# %% [markdown]
# #  Homework 4
# ## MBIO612
# ### Gabrielle Martineau

# %%
#Set working directory
setwd("~/U_of_H/FALL_2021/MBIO612/Week_5")

library("tidyverse")
# Out:
# Warning message:
# "package 'tidyverse' was built under R version 3.6.3"-- Attaching packages --------------------------------------- tidyverse 1.3.1 --
# v ggplot2 3.3.5     v purrr   0.3.4
# v tibble  3.1.1     v dplyr   1.0.6
# v tidyr   1.1.3     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
# Warning message:
# "package 'tibble' was built under R version 3.6.3"Warning message:
# "package 'tidyr' was built under R version 3.6.3"Warning message:
# "package 'readr' was built under R version 3.6.3"Warning message:
# "package 'purrr' was built under R version 3.6.3"Warning message:
# "package 'dplyr' was built under R version 3.6.3"Warning message:
# "package 'stringr' was built under R version 3.6.3"Warning message:
# "package 'forcats' was built under R version 3.6.3"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %% [markdown]
# ## Question 0

# %%
######################
#### Exo 0############
######################


replace_na_mean <- function(x){
  mean (x, na.rm=TRUE)
}

replace_na_mean(c(1, NA, 2, 3, 2, 2, NA))
# Out:
# [1] 2

# %% [markdown]
# ## Question 1

# %%
######################
#### Exo 1############
######################

get_all_perms <- function(){
  (expand.grid (0:9, 0:9,0:9, 0:9))
}

  get_all_perms()
# Out:
#       Var1 Var2 Var3 Var4
# 1     0    0    0    0
# 2     1    0    0    0
# 3     2    0    0    0
# 4     3    0    0    0
# 5     4    0    0    0
# 6     5    0    0    0
# 7     6    0    0    0
# 8     7    0    0    0
# 9     8    0    0    0
# 10    9    0    0    0
# 11    0    1    0    0
# 12    1    1    0    0
# 13    2    1    0    0
# 14    3    1    0    0
# 15    4    1    0    0
# 16    5    1    0    0
# 17    6    1    0    0
# 18    7    1    0    0
# 19    8    1    0    0
# 20    9    1    0    0
# 21    0    2    0    0
# 22    1    2    0    0
# 23    2    2    0    0
# 24    3    2    0    0
# 25    4    2    0    0
# 26    5    2    0    0
# 27    6    2    0    0
# 28    7    2    0    0
# 29    8    2    0    0
# 30    9    2    0    0
# ...   ...  ...  ...  ...
# 9971  0    7    9    9
# 9972  1    7    9    9
# 9973  2    7    9    9
# 9974  3    7    9    9
# 9975  4    7    9    9
# 9976  5    7    9    9
# 9977  6    7    9    9
# ...

# %% [markdown]
# ## Question 2

# %%
######################
#### Exo 2############
######################

  get_all_perms <- function(size){
    replicate(size, c(0:9), simplify = FALSE)  %>%expand.grid
  }


  get_all_perms(size=4)
# Out:
#       Var1 Var2 Var3 Var4
# 1     0    0    0    0
# 2     1    0    0    0
# 3     2    0    0    0
# 4     3    0    0    0
# 5     4    0    0    0
# 6     5    0    0    0
# 7     6    0    0    0
# 8     7    0    0    0
# 9     8    0    0    0
# 10    9    0    0    0
# 11    0    1    0    0
# 12    1    1    0    0
# 13    2    1    0    0
# 14    3    1    0    0
# 15    4    1    0    0
# 16    5    1    0    0
# 17    6    1    0    0
# 18    7    1    0    0
# 19    8    1    0    0
# 20    9    1    0    0
# 21    0    2    0    0
# 22    1    2    0    0
# 23    2    2    0    0
# 24    3    2    0    0
# 25    4    2    0    0
# 26    5    2    0    0
# 27    6    2    0    0
# 28    7    2    0    0
# 29    8    2    0    0
# 30    9    2    0    0
# ...   ...  ...  ...  ...
# 9971  0    7    9    9
# 9972  1    7    9    9
# 9973  2    7    9    9
# 9974  3    7    9    9
# 9975  4    7    9    9
# 9976  5    7    9    9
# 9977  6    7    9    9
# ...

# %% [markdown]
# ## Question 3

# %%
######################
#### Exo 3############
######################

animal_disease = sample(c("disease", "healthy"), size=340, replace=TRUE, prob=c(0.43, 0.57))
animal_disease

  animal_disease_function <- function (x){     
    sum (x== "disease")
  }

  animal_disease_function(animal_disease)
# Out:
#   [1] "healthy" "healthy" "healthy" "healthy" "disease" "disease" "healthy"
#   [8] "healthy" "disease" "healthy" "disease" "healthy" "healthy" "disease"
#  [15] "healthy" "healthy" "disease" "healthy" "healthy" "healthy" "disease"
#  [22] "healthy" "healthy" "disease" "disease" "healthy" "healthy" "healthy"
#  [29] "disease" "healthy" "healthy" "healthy" "healthy" "healthy" "disease"
#  [36] "disease" "healthy" "disease" "healthy" "disease" "disease" "healthy"
#  [43] "healthy" "disease" "healthy" "healthy" "healthy" "healthy" "healthy"
#  [50] "disease" "healthy" "healthy" "healthy" "healthy" "disease" "healthy"
#  [57] "disease" "healthy" "healthy" "healthy" "disease" "disease" "disease"
#  [64] "healthy" "healthy" "disease" "disease" "healthy" "disease" "disease"
#  [71] "healthy" "healthy" "healthy" "healthy" "disease" "healthy" "healthy"
#  [78] "healthy" "healthy" "disease" "disease" "disease" "disease" "healthy"
# ...

# %% [markdown]
# ## Question 4

# %%
  
  ######################
  #### Exo 4############
  ######################
  
#Plot distribution 1 and 2
 
  x_vals = seq(5,15, 0.25)
  set.seed(42)
  x_sample= mapply(dnorm, x_vals, mean= 10, sd=0.5)
  y_sample= mapply(dnorm, x_vals, mean= 10.2, sd=0.5)
 
  
  Graph_1 <- 
    ggplot() + 
    geom_line(aes(x=x_vals, y= x_sample), size=3, color="blue") +
    geom_line(aes(x=x_vals, y= y_sample), size=3, color= "red") +
    theme(axis.title.x = element_text(size = 24), axis.title.y = element_text(size = 24)) + 
    theme(axis.text.x = element_text(size = 18), axis.text.y = element_text(size = 18))
  
  Graph_1 
  
#Compute t-test
  t.test(x_sample,y_sample)
# Out:
# 	Welch Two Sample t-test
#
# data:  x_sample and y_sample
# t = 0, df = 80, p-value = 1
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.09494578  0.09494578
# sample estimates:
#  mean of x  mean of y
# 0.09756098 0.09756098
# plot without title

# %% [markdown]
# The p-value is inferior to 0.05, meaning that there is a significant difference  in those 2 distributions

# %% [markdown]
# ## Question 5. Not sure I understood correctly the quesiton

# %%
 ######################
  #### Exo 5############
  ######################
  
  #Plot distribution 1 and 2
  
  x1_vals = seq(8,12, 0.1)
  x_sample= mapply(dnorm, x1_vals, mean= 10, sd=0.5)
  y_sample= mapply(dnorm, x1_vals, mean= 10.2, sd=0.5)
  
  
  Graph_3 <- 
    ggplot() + 
    geom_line(aes(x=x1_vals, y= x_sample), size=3, color="blue") +
    geom_line(aes(x=x1_vals, y= y_sample), size=3, color= "red") +
    theme(axis.title.x = element_text(size = 24), axis.title.y = element_text(size = 24)) + 
    theme(axis.text.x = element_text(size = 18), axis.text.y = element_text(size = 18))
  
  Graph_3

  #compute density function

  t_test_density <- mapply(dnorm, x1_vals, mean= 10, sd=0.5)
  t.test(x_sample, t_test_density)
# Out:
# 	Welch Two Sample t-test
#
# data:  x_sample and t_test_density
# t = 0, df = 80, p-value = 1
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1243778  0.1243778
# sample estimates:
# mean of x mean of y
# 0.2438927 0.2438927
# plot without title
